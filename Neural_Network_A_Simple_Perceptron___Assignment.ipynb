# %% [markdown]
# Question 1: What is Deep Learning? Briefly describe how it evolved and how it differs
# from traditional machine learning

# %% [markdown]
# Deep Learning is a subset of Machine Learning that uses Artificial Neural Networks (ANNs) with multiple hidden layers to learn patterns from large amounts of data automatically. It is inspired by the structure and functioning of the human brain.
#
# Deep learning models can automatically extract features from data such as images, audio, text, and videos without requiring manual feature engineering.
#
# Basic Structure of Deep Learning Network
#
# A deep neural network generally contains:
#
# Input Layer – receives input data
# Hidden Layers – process and learn complex patterns
# Output Layer – produces the final result
#
# Example applications:
#
# Image Recognition
# Speech Recognition
# Natural Language Processing (NLP)
# Self-driving Cars
# Recommendation Systems
# Evolution of Deep Learning
# 1. Early Neural Networks (1940s–1980s)
# Initial ideas of artificial neurons were introduced.
# Simple models like the Perceptron were developed.
# Limited computing power and data restricted progress.
# 2. Machine Learning Era (1990s–2000s)
# Traditional machine learning algorithms became popular:
# Decision Trees
# Support Vector Machines (SVM)
# Naive Bayes
# Feature extraction was mostly done manually.
# 3. Rise of Deep Learning (2006 onwards)
# Improvements in:
# GPU computing
# Availability of big data
# Better algorithms (Backpropagation, ReLU, etc.)
# Researchers successfully trained deep neural networks with many layers.
# 4. Modern Deep Learning
#
# Deep learning now powers:
#
# Virtual assistants
# Chatbots
# Medical diagnosis
# Face recognition
# Generative AI systems
#
# Popular frameworks include:
#
# TensorFlow
# PyTorch
# Keras

# %% [markdown]
# Question 2: Explain the basic architecture and functioning of a Perceptron. What are its
# limitations?

# %% [markdown]
# A Perceptron is the simplest type of Artificial Neural Network (ANN) developed by Frank Rosenblatt in 1958.
# It is mainly used for binary classification problems, where the output is either 0 or 1.
#
# A perceptron acts like an artificial neuron that receives inputs, processes them, and produces an output.
#
# Basic Architecture of a Perceptron
#
# A perceptron consists of the following components:
#
# Input Values (x₁, x₂, x₃, …)
# Features or data provided to the model.
# Weights (w₁, w₂, w₃, …)
# Each input has an associated weight.
# Weights determine the importance of inputs.
# Bias (b)
# Helps shift the decision boundary.
# Summation Function
# Computes the weighted sum of inputs.
# Activation Function
# Produces the final output based on the weighted sum.
# Perceptron Equation
#
# The net input is calculated as:
#
# z=∑
# i=1
# n
# 	​
#
# w
# i
# 	​
#
# x
# i
# 	​
#
# +b
#
# The output is then determined using a step activation function:
#
# y={
# 1,
# 0,
# 	​
#
# z>0
# z≤0
# 	​
#
#
# Where:
#
# x
# i
# 	​
#
#  = input values
# w
# i
# 	​
#
#  = weights
# b = bias
# z = weighted sum
# y = output
# Functioning of a Perceptron
#
# The working of a perceptron can be explained in the following steps:
#
# Step 1: Receive Inputs
#
# The perceptron accepts input data values.
#
# Example:
#
# x
# 1
# 	​
#
# =2,x
# 2
# 	​
#
# =3
# Step 2: Multiply Inputs by Weights
#
# Each input is multiplied by its corresponding weight.
#
# w
# 1
# 	​
#
# x
# 1
# 	​
#
# +w
# 2
# 	​
#
# x
# 2
# 	​
#
# Step 3: Add Bias
#
# Bias is added to the weighted sum.
#
# z=w
# 1
# 	​
#
# x
# 1
# 	​
#
# +w
# 2
# 	​
#
# x
# 2
# 	​
#
# +b
# Step 4: Apply Activation Function
#
# The activation function decides the final output:
#
# Output = 1 → Positive class
# Output = 0 → Negative class
# Step 5: Learning Process
#
# During training:
#
# If prediction is wrong, weights are updated.
# The perceptron learning rule adjusts weights to reduce errors.
#
# Weight update rule:
#
# w
# new
# 	​
#
# =w
# old
# 	​
#
# +η(y
# actual
# 	​
#
# −y
# predicted
# 	​
#
# )x
#
# Where:
#
# η = learning rate
# Advantages of Perceptron
# Simple and easy to implement
# Fast for small problems
# Useful for linearly separable data
# Forms the foundation of neural networks
# Limitations of Perceptron
# 1. Cannot Solve Non-Linear Problems
#
# A single-layer perceptron can only classify linearly separable data.
#
# Example:
#
# It cannot solve the XOR problem.
# 2. Limited Learning Capability
# Handles only simple classification tasks.
# Cannot learn highly complex patterns.
# 3. Binary Output Only
# Produces only two classes:
# 0 or 1
# Not suitable for multi-class problems directly.
# 4. No Hidden Layers
# Single-layer perceptron lacks hidden layers.
# Therefore, it cannot perform deep feature extraction.
# 5. Sensitive to Data
# Performance depends heavily on:
# learning rate
# initial weights
# quality of training data

# %% [markdown]
# Question 3: Describe the purpose of activation function in neural networks. Compare
# Sigmoid, ReLU, and Tanh functions.

# %% [markdown]
# An activation function is a mathematical function used in neural networks to determine whether a neuron should be activated or not. It converts the weighted input into an output signal that is passed to the next layer.
#
# Without activation functions, a neural network would behave like a simple linear model and would not be able to learn complex patterns.
#
# Why Activation Functions are Important
# 1. Introduce Non-Linearity
#
# Activation functions allow neural networks to learn:
#
# complex relationships
# patterns
# non-linear data
#
# Without non-linearity, deep neural networks cannot solve real-world problems effectively.
#
# 2. Control Output
#
# They help control the output range of neurons.
#
# Example:
#
# Sigmoid outputs values between 0 and 1.
# Tanh outputs values between −1 and 1.
# 3. Improve Learning Ability
#
# Activation functions help neural networks:
#
# classify data
# recognize images
# understand speech and text
# make predictions
# Common Activation Functions
# 1. Sigmoid Function
#
# The sigmoid function converts input values into a range between 0 and 1.
#
# σ(x)=
# 1+e
# −x
# 1
# 	​
#
#
# Characteristics
# Output range: 0 to 1
# Produces smooth curves
# Commonly used in binary classification output layers
# Advantages
# Easy to understand
# Useful for probability prediction
# Disadvantages
# Suffers from vanishing gradient problem
# Slow training for deep networks
# Output not centered around zero
# 2. ReLU (Rectified Linear Unit)
#
# ReLU outputs the input directly if it is positive; otherwise, it returns 0.
#
# f(x)=max(0,x)
#
# Characteristics
# Output range: 0 to ∞
# Most widely used activation function in deep learning
# Advantages
# Computationally fast
# Reduces vanishing gradient problem
# Enables faster training
# Disadvantages
# Can suffer from dying ReLU problem
# neurons may stop learning if output becomes 0 permanently
# 3. Tanh (Hyperbolic Tangent)
#
# Tanh converts input values into a range between −1 and 1.
#
# tanh(x)=
# e
# x
# +e
# −x
# e
# x
# −e
# −x
# 	​
#
#
# Characteristics
# Output range: −1 to 1
# Zero-centered activation
# Advantages
# Better than sigmoid for hidden layers
# Stronger gradients than sigmoid
# Disadvantages
# Still suffers from vanishing gradient problem
# Computationally expensive compared to ReLU

# %% [markdown]
# Question 4: What is the difference between Loss function and Cost function in neural
# networks? Provide examples.

# %% [markdown]
# | Loss Function                                | Cost Function                             |
# | -------------------------------------------- | ----------------------------------------- |
# | Measures error for one training example      | Measures average error for entire dataset |
# | Calculated per sample                        | Calculated over all samples               |
# | Used during individual prediction evaluation | Used during optimization and training     |
# | Example: loss for one image                  | Example: average loss for all images      |

# %% [markdown]
# Question 5: What is the role of optimizers in neural networks? Compare Gradient
# Descent, Adam, and RMSprop

# %% [markdown]
# Role of Optimizers in Neural Networks
# Introduction
#
# An Optimizer is an algorithm used in neural networks to improve the model’s performance by minimizing the loss (error) function.
#
# During training, the optimizer updates the:
#
# weights
# biases
#
# so that the neural network can make more accurate predictions.
#
# Optimizers work together with:
#
# backpropagation
# loss functions
# gradients
#
# to train the model efficiently.
#
# Role of Optimizers
# 1. Minimize Loss Function
#
# The main goal of an optimizer is to reduce prediction error.
#
# It adjusts weights to achieve the minimum value of the loss function.
#
# 2. Improve Accuracy
#
# By continuously updating parameters, optimizers help the model learn patterns and improve prediction accuracy.
#
# 3. Speed Up Training
#
# Efficient optimizers reduce training time and improve convergence speed.
#
# 4. Handle Large Neural Networks
#
# Modern optimizers can efficiently train deep neural networks with millions of parameters.
#
# 1. Gradient Descent Optimizer
# Definition
#
# Gradient Descent is the basic optimization algorithm used to minimize the loss function by moving in the direction of the negative gradient.
#
# Weight update rule:
#
# w
# new
# 	​
#
# =w
# old
# 	​
#
# −η
# ∂w
# ∂L
# 	​
#
#
# Where:
#
# η = learning rate
# ∂w
# ∂L
# 	​
#
#  = gradient of loss
# Working
# Calculate loss
# Compute gradients
# Update weights
# Repeat until minimum loss is reached
# Advantages
# Simple and easy to understand
# Works well for small datasets
# Disadvantages
# Slow convergence
# Can get stuck in local minima
# Sensitive to learning rate
# 2. RMSprop Optimizer
# Definition
#
# RMSprop (Root Mean Square Propagation) improves Gradient Descent by adapting the learning rate for each parameter.
#
# It uses moving averages of squared gradients.
#
# Update formula:
#
# E[g
# 2
# ]
# t
# 	​
#
# =βE[g
# 2
# ]
# t−1
# 	​
#
# +(1−β)g
# t
# 2
# 	​
#
#
# Advantages
# Faster convergence
# Works well for recurrent neural networks (RNNs)
# Handles varying gradients effectively
# Disadvantages
# Requires tuning of hyperparameters
# Sometimes unstable
# 3. Adam Optimizer
# Definition
#
# Adam (Adaptive Moment Estimation) combines:
#
# Momentum
# RMSprop
#
# It is one of the most popular optimizers in deep learning.
#
# Adam uses:
#
# moving average of gradients
# moving average of squared gradients
# Advantages
# Fast and efficient
# Requires less memory
# Works well for large datasets and deep networks
# Adaptive learning rates
# Disadvantages
# Can sometimes generalize poorly compared to SGD
# More computationally complex

# %% [markdown]
# Question 6: Write a Python program to implement a single-layer perceptron from
# scratch using NumPy to solve the logical AND gate

# %%
import numpy as np

# Input dataset for AND gate
# x1, x2
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# Expected output
y = np.array([0, 0, 0, 1])

# Initialize weights and bias
weights = np.zeros(2)
bias = 0

# Learning rate
learning_rate = 0.1

# Number of epochs
epochs = 10

# Activation function (Step Function)
def activation_function(x):
    if x >= 0:
        return 1
    else:
        return 0

# Training the perceptron
for epoch in range(epochs):

    print(f"\nEpoch {epoch + 1}")

    for i in range(len(X)):

        # Calculate weighted sum
        weighted_sum = np.dot(X[i], weights) + bias

        # Predicted output
        y_pred = activation_function(weighted_sum)

        # Calculate error
        error = y[i] - y_pred

        # Update weights and bias
        weights = weights + learning_rate * error * X[i]
        bias = bias + learning_rate * error

        # Print updates
        print(f"Input: {X[i]}, Target: {y[i]}, Predicted: {y_pred}, Error: {error}")

# Final weights and bias
print("\nFinal Weights:", weights)
print("Final Bias:", bias)

# Testing the perceptron
print("\nTesting AND Gate")

for i in range(len(X)):
    weighted_sum = np.dot(X[i], weights) + bias
    output = activation_function(weighted_sum)

    print(f"{X[i]} --> {output}")
# Out:
# Epoch 1
# Input: [0 0], Target: 0, Predicted: 1, Error: -1
# Input: [0 1], Target: 0, Predicted: 0, Error: 0
# Input: [1 0], Target: 0, Predicted: 0, Error: 0
# Input: [1 1], Target: 1, Predicted: 0, Error: 1
#
# Epoch 2
# Input: [0 0], Target: 0, Predicted: 1, Error: -1
# Input: [0 1], Target: 0, Predicted: 1, Error: -1
# Input: [1 0], Target: 0, Predicted: 0, Error: 0
# Input: [1 1], Target: 1, Predicted: 0, Error: 1
#
# Epoch 3
# Input: [0 0], Target: 0, Predicted: 0, Error: 0
# Input: [0 1], Target: 0, Predicted: 1, Error: -1
# Input: [1 0], Target: 0, Predicted: 1, Error: -1
# Input: [1 1], Target: 1, Predicted: 0, Error: 1
#
# Epoch 4
# Input: [0 0], Target: 0, Predicted: 0, Error: 0
# Input: [0 1], Target: 0, Predicted: 0, Error: 0
# Input: [1 0], Target: 0, Predicted: 0, Error: 0
# Input: [1 1], Target: 1, Predicted: 1, Error: 0
#
# Epoch 5
# Input: [0 0], Target: 0, Predicted: 0, Error: 0
# Input: [0 1], Target: 0, Predicted: 0, Error: 0
# ...

# %% [markdown]
# Question 7: Implement and visualize Sigmoid, ReLU, and Tanh activation functions
# using Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate input values
x = np.linspace(-10, 10, 1000)

# Activation Functions
sigmoid = 1 / (1 + np.exp(-x))
relu = np.maximum(0, x)
tanh = np.tanh(x)

# Sigmoid Plot
plt.figure(figsize=(6,4))
plt.plot(x, sigmoid)
plt.title("Sigmoid Activation Function")
plt.xlabel("x")
plt.ylabel("Sigmoid(x)")
plt.grid(True)
plt.show()

# ReLU Plot
plt.figure(figsize=(6,4))
plt.plot(x, relu)
plt.title("ReLU Activation Function")
plt.xlabel("x")
plt.ylabel("ReLU(x)")
plt.grid(True)
plt.show()

# Tanh Plot
plt.figure(figsize=(6,4))
plt.plot(x, tanh)
plt.title("Tanh Activation Function")
plt.xlabel("x")
plt.ylabel("Tanh(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# Question 8: Use Keras to build and train a simple multilayer neural network on the
# MNIST digits dataset. Print the training accuracy.

# %%
# Import required libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# Build the Multilayer Neural Network
model = Sequential([
    Flatten(input_shape=(28, 28)),     # Input layer
    Dense(128, activation='relu'),     # Hidden layer 1
    Dense(64, activation='relu'),      # Hidden layer 2
    Dense(10, activation='softmax')    # Output layer
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=32,
    validation_split=0.1
)

# Print training accuracy
training_accuracy = history.history['accuracy'][-1]

print("\nTraining Accuracy:", training_accuracy)

# Evaluate on test data
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_accuracy)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9249 - loss: 0.2521 - val_accuracy: 0.9683 - val_loss: 0.1053
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9664 - loss: 0.1089 - val_accuracy: 0.9742 - val_loss: 0.0836
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9767 - loss: 0.0751 - val_accuracy: 0.9775 - val_loss: 0.0797
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9828 - loss: 0.0552 - val_accuracy: 0.9777 - val_loss: 0.0813
# Epoch 5/5
# ...

# %% [markdown]
# Question 9: Visualize the loss and accuracy curves for a neural network model trained
# on the Fashion MNIST dataset. Interpret the training behavio

# %%
# Import required libraries
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import fashion_mnist

# Load Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# Build Neural Network Model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.1
)

# Plot Accuracy Curve
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot Loss Curve
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8216 - loss: 0.5016 - val_accuracy: 0.8562 - val_loss: 0.3903
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8631 - loss: 0.3724 - val_accuracy: 0.8685 - val_loss: 0.3598
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8758 - loss: 0.3374 - val_accuracy: 0.8738 - val_loss: 0.3476
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8842 - loss: 0.3138 - val_accuracy: 0.8755 - val_loss: 0.3325
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8900 - loss: 0.2967 - val_accuracy: 0.8807 - val_loss: 0.3346
# Epoch 6/10
# ...

# %% [markdown]
# Question 10: You are working on a project for a bank that wants to automatically detect
# fraudulent transactions. The dataset is large, imbalanced, and contains structured
# features like transaction amount, merchant ID, and customer location. The goal is to
# classify each transaction as fraudulent or legitimate.
# Explain your real-time data science workflow:
# ● How would you design a deep learning model (perceptron or multilayer NN)?
# ● Which activation function and loss function would you use, and why?
# ● How would you train and evaluate the model, considering class imbalance?
# ● Which optimizer would be suitable, and how would you prevent overfitting?

# %% [markdown]
# Fraud Detection System Using Deep Learning
# Introduction
#
# In a banking fraud detection system, the goal is to classify transactions as:
#
# Fraudulent
# Legitimate
#
# The dataset is:
#
# large
# structured
# highly imbalanced
#
# Features may include:
#
# transaction amount
# merchant ID
# customer location
# transaction time
# device information
#
# Since fraud detection is a binary classification problem, a Multilayer Neural Network (MLP) is more suitable than a single perceptron because fraud patterns are usually complex and non-linear.
#
# 1. Designing the Deep Learning Model
# Why Not a Single Perceptron?
#
# A single perceptron can only solve linearly separable problems. Fraud detection involves:
#
# hidden patterns
# non-linear relationships
# complex feature interactions
#
# Therefore, a Multilayer Neural Network (MLP) should be used.
#
# Proposed Neural Network Architecture
# Input Layer
#
# Receives structured transaction features:
#
# amount
# merchant ID
# customer location
# frequency of transactions
# transaction type
# Hidden Layers
#
# Use multiple dense layers to learn complex fraud patterns.
#
# Example architecture:
#
# Input Layer
#    ↓
# Dense Layer (128 neurons, ReLU)
#    ↓
# Dropout Layer
#    ↓
# Dense Layer (64 neurons, ReLU)
#    ↓
# Dense Layer (32 neurons, ReLU)
#    ↓
# Output Layer (1 neuron, Sigmoid)
#
# Output Layer
#
# Since this is binary classification:
#
# 0 → Legitimate
# 1 → Fraudulent
#
# Use 1 neuron with Sigmoid activation.
#
# 2. Activation Function and Loss Function
# Activation Function
# Hidden Layers → ReLU
#
# f(x)=max(0,x)
#
# Why ReLU?
# Fast computation
# Reduces vanishing gradient problem
# Works well in deep networks
# Efficient for large datasets
# Output Layer → Sigmoid
#
# σ(x)=
# 1+e
# −x
# 1
# 	​
#
#
# Why Sigmoid?
# Produces output between 0 and 1
# Interpretable as fraud probability
#
# Example:
#
# 0.95 → highly fraudulent
# 0.02 → legitimate
# Loss Function
# Binary Cross-Entropy Loss
#
# L=−[ylog(
# y
# ^
# 	​
#
# )+(1−y)log(1−
# y
# ^
# 	​
#
# )]
#
# Why Binary Cross-Entropy?
# Best suited for binary classification
# Penalizes wrong predictions strongly
# Works well with sigmoid output
# 3. Training and Evaluation Considering Class Imbalance
# Problem of Imbalanced Data
#
# Fraud datasets are highly imbalanced:
#
# Example:
#
# 99% legitimate transactions
# 1% fraudulent transactions
#
# A normal model may predict all transactions as legitimate and still achieve high accuracy.
#
# Therefore, accuracy alone is not sufficient.
#
# Handling Class Imbalance
# 1. Class Weights
#
# Assign higher penalty to fraudulent class during training.
#
# Example:
#
# Fraud class gets larger weight
#
# This forces the model to pay more attention to fraud cases.
#
# 2. Oversampling
#
# Increase fraud samples using:
#
# SMOTE
# Random Oversampling
# 3. Undersampling
#
# Reduce legitimate samples to balance classes.
#
# 4. Balanced Batch Training
#
# Ensure each batch contains sufficient fraud examples
#
# | Metric           | Purpose                                     |
# | ---------------- | ------------------------------------------- |
# | Precision        | How many detected frauds are actually fraud |
# | Recall           | How many actual frauds were detected        |
# | F1-Score         | Balance between precision and recall        |
# | ROC-AUC          | Overall classification performance          |
# | Confusion Matrix | Detailed prediction analysis                |
#
# Important Metric → Recall
#
# In fraud detection:
#
# Missing a fraud is very costly.
#
# Therefore, high recall is extremely important.
#
# 4. Suitable Optimizer
# Adam Optimizer
#
# Adam combines:
#
# Momentum
# RMSprop
# Why Adam?
# Fast convergence
# Adaptive learning rates
# Works well on large datasets
# Efficient for deep learning
#
# Weight update rule:
#
# w
# new
# 	​
#
# =w
# old
# 	​
#
# −η
# ∂w
# ∂L
# 	​
#
#
# 5. Preventing Overfitting
#
# Overfitting occurs when the model memorizes training data instead of learning general patterns.
#
# Techniques to Prevent Overfitting
# 1. Dropout Layers
#
# Randomly deactivate neurons during training.
#
# Example:
#
# Dropout(0.5)
#
# Helps improve generalization.
#
# 2. Early Stopping
#
# Stop training when validation loss stops improving.
#
# 3. Regularization
#
# Use L1/L2 regularization to reduce overly large weights.
#
# 4. Cross-Validation
#
# Validate model on different subsets of data.
#
# 5. More Data
#
# Use larger and more diverse fraud samples.
#
# Real-Time Deployment Workflow
# Step-by-Step Workflow
#
# Transaction Data
#       ↓
# Data Cleaning & Feature Engineering
#       ↓
# Data Normalization
#       ↓
# Train/Test Split
#       ↓
# Multilayer Neural Network Training
#       ↓
# Model Evaluation
#       ↓
# Fraud Probability Prediction
#       ↓
# Real-Time Fraud Alert System
